# %%
from google.colab import drive

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pip install pandas numpy matplotlib openpyxl ipywidgets seaborn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 23.6 MB/s eta 0:00:00
# ...

# %%
import pandas as pd

# %%
# File path
file_path = '/content/gdrive/My Drive/python/GLB.Ts+dSST.xlsx'

# Load data into a pandas DataFrame
df = pd.read_excel(file_path)

# %%
df.head()
# Out:
#    Year   Jan   Feb   Mar   Apr   May   Jun   Jul   Aug   Sep   Oct   Nov  \
# 0  1880 -0.20 -0.26 -0.09 -0.17 -0.10 -0.22 -0.20 -0.11 -0.16 -0.23 -0.23
# 1  1881 -0.20 -0.16  0.02  0.04  0.06 -0.19  0.01 -0.04 -0.16 -0.22 -0.19
# 2  1882  0.16  0.13  0.04 -0.16 -0.14 -0.23 -0.16 -0.08 -0.15 -0.24 -0.17
# 3  1883 -0.29 -0.37 -0.12 -0.18 -0.18 -0.07 -0.07 -0.14 -0.22 -0.12 -0.24
# 4  1884 -0.13 -0.08 -0.36 -0.40 -0.34 -0.35 -0.31 -0.28 -0.27 -0.25 -0.34
#
#     Dec   Average
# 0 -0.19 -0.180000
# 1 -0.08 -0.092500
# 2 -0.36 -0.113333
# 3 -0.11 -0.175833
# 4 -0.31 -0.285000

# %%
# Check the column names in the dataframe
print(df.columns)
# Out:
# Index(['Year', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep',
#        'Oct', 'Nov', 'Dec', 'Average'],
#       dtype='object')

# %%
# Path to the dataset on your Google Drive
file_path1 = '/content/gdrive/My Drive/python/climate_change_indicators.csv'

df_climate_data = pd.read_csv(file_path1)

# %%
# Display the first few rows of the dataset to inspect it
df_climate_data.head()
# Out:
#    ObjectId                       Country ISO2 ISO3  \
# 0         1  Afghanistan, Islamic Rep. of   AF  AFG
# 1         2                       Albania   AL  ALB
# 2         3                       Algeria   DZ  DZA
# 3         4                American Samoa   AS  ASM
# 4         5      Andorra, Principality of   AD  AND
#
#                                            Indicator            Unit  \
# 0  Temperature change with respect to a baseline ...  Degree Celsius
# 1  Temperature change with respect to a baseline ...  Degree Celsius
# 2  Temperature change with respect to a baseline ...  Degree Celsius
# 3  Temperature change with respect to a baseline ...  Degree Celsius
# 4  Temperature change with respect to a baseline ...  Degree Celsius
#
#                                               Source CTS_Code  \
# 0  Food and Agriculture Organization of the Unite...     ECCS
# 1  Food and Agriculture Organization of the Unite...     ECCS
# ...

# %%
# Select only the columns related to temperature (those starting with 'F')
temperature_columns = [col for col in df_climate_data.columns if col.startswith('F')]

# Create a new DataFrame with just the 'Country' column and the temperature data
df_temperature = df_climate_data[['Country'] + temperature_columns]
# Fill missing values with 0 (or apply any other technique if needed)
df_temperature = df_temperature.fillna(0)

# Display the cleaned data
df_temperature.head()
# Out:
#                         Country  F1961  F1962  F1963  F1964  F1965  F1966  \
# 0  Afghanistan, Islamic Rep. of -0.113 -0.164  0.847 -0.764 -0.244  0.226
# 1                       Albania  0.627  0.326  0.075 -0.166 -0.388  0.559
# 2                       Algeria  0.164  0.114  0.077  0.250 -0.100  0.433
# 3                American Samoa  0.079 -0.042  0.169 -0.140 -0.562  0.181
# 4      Andorra, Principality of  0.736  0.112 -0.752  0.308 -0.490  0.415
#
#    F1967  F1968  F1969  ...  F2013  F2014  F2015  F2016  F2017  F2018  F2019  \
# 0 -0.371 -0.423 -0.539  ...  1.281  0.456  1.093  1.555  1.540  1.544  0.910
# 1 -0.074  0.081 -0.013  ...  1.333  1.198  1.569  1.464  1.121  2.028  1.675
# 2 -0.026 -0.067  0.291  ...  1.192  1.690  1.121  1.757  1.512  1.210  1.115
# 3 -0.368 -0.187  0.132  ...  1.257  1.170  1.009  1.539  1.435  1.189  1.539
# 4  0.637  0.018 -0.137  ...  0.831  1.946  1.690  1.990  1.925  1.919  1.964
#
#    F2020  F2021  F2022
# 0  0.498  1.327  2.012
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from ipywidgets import interact

# %%
# Plot average temperature anomaly by year
plt.figure(figsize=(12, 6))
plt.plot(df['Year'], df['Average'], label='Average Temperature Anomaly')
plt.xlabel('Year')
plt.ylabel('Temperature Anomaly (°C)')
plt.title('Average Global Temperature Anomaly Over Time')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Create a function to plot the monthly temperature anomaly for a selected year
def plot_monthly_data(year):
    # Filter data for the selected year
    monthly_data = df[df['Year'] == year].iloc[:, 1:-1].T  # Select month columns
    monthly_data.columns = ['Temperature Anomaly']

    # Plot the data
    plt.figure(figsize=(10, 5))
    monthly_data.plot(kind='bar', color='skyblue')
    plt.title(f'Monthly Temperature Anomaly for {year}')
    plt.xlabel('Month')
    plt.ylabel('Temperature Anomaly (°C)')
    plt.xticks(rotation=45)
    plt.show()

# Create the interactive widget for selecting a year
interact(plot_monthly_data, year=(1880, 2024, 1))
# Out:
# interactive(children=(IntSlider(value=1952, description='year', max=2024, min=1880), Output()), _dom_classes=(…
# <function __main__.plot_monthly_data(year)>

# %%
# Select only the columns for the months and year
monthly_data = df.iloc[:, 1:-1]

# Set the 'Year' column as the index
monthly_data.index = df['Year']

# Create a heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(monthly_data, cmap='coolwarm', annot=False, fmt='.2f', cbar_kws={'label': 'Temperature Anomaly (°C)'})
plt.title('Monthly Global Temperature Anomalies (1880 - 2024)')
plt.xlabel('Month')
plt.ylabel('Year')
plt.show()

# %%
import ipywidgets as widgets
from ipywidgets import interact

# %%
def plot_temperature_changes(country):
    # Filter the data for the selected country
    country_data = df_temperature[df_temperature['Country'] == country].iloc[0, 1:]

    # Sort the temperature data to find the top 3 largest and smallest changes
    sorted_data = country_data.sort_values()

    # Get the top 3 smallest and top 3 largest temperature changes
    top_3_smallest = sorted_data.head(3)
    top_3_largest = sorted_data.tail(3)

    # Plot the results
    plt.figure(figsize=(12, 6))

    # Plot top 3 smallest temperature changes
    plt.subplot(1, 2, 1)
    top_3_smallest.plot(kind='bar', color='red', title=f'Top 3 Smallest Temperature Changes ({country})')
    plt.xlabel('Year')
    plt.ylabel('Temperature Change (°C)')

    # Plot top 3 largest temperature changes
    plt.subplot(1, 2, 2)
    top_3_largest.plot(kind='bar', color='green', title=f'Top 3 Largest Temperature Changes ({country})')
    plt.xlabel('Year')
    plt.ylabel('Temperature Change (°C)')

    plt.tight_layout()
    plt.show()

# %%
# Create a dropdown widget for selecting a country
country_widget = widgets.Dropdown(
    options=df_climate_data['Country'].unique(),  # Get unique countries from the dataset
    description='Country:',
    disabled=False
)

# Use the interact function to link the dropdown to the plotting function
interact(plot_temperature_changes, country=country_widget)
# Out:
# interactive(children=(Dropdown(description='Country:', options=('Afghanistan, Islamic Rep. of', 'Albania', 'Al…
# <function __main__.plot_temperature_changes(country)>
